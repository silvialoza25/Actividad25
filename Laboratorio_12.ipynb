# %% [markdown]
# <a href="https://colab.research.google.com/github/silvialoza25/Actividad25/blob/main/Laboratorio_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Prompt 1: Crea un codigo python donde cargarás el dataset Diabetes de scikit-learn, que contiene
# variables relacionadas con la salud y una variable de salida (target) que mide el nivel de
# progreso de la enfermedad. Los datos serán organizados en un DataFrame para
# facilitar el manejo.
# 2. Tareas:
# o Importar las librerías necesarias.
# o Cargar los datos utilizando load_diabetes y convertirlos a un DataFrame con
# pandas.
# o Mostrar las primeras filas del DataFrame para explorar los datos

# %% [markdown]
# Prompt 2: Crea un codigo python pero En esta sección, aplicarás un modelo de regresión lineal para predecir los
# valores del target (progresión de la enfermedad) en función del índice de masa
# corporal (BMI), una de las variables predictoras.
# 2. Tareas:
# Laboratorio 12
# o Dividir los datos en conjuntos de entrenamiento y prueba usando
# train_test_split.
# o Entrenar un modelo de regresión lineal con la variable BMI como predictora.
# o Evaluar el modelo utilizando el error cuadrático medio (MSE) como métrica.

# %% [markdown]
# Prompt 3: Crea un codigo python donde Aplicarás un modelo de regresión logística para clasificar si el valor del
# target es mayor que 140. Esto convierte el problema en un problema de clasificación
# binaria.
# 2. Tareas:
# o Convertir la variable dependiente (target) en binaria.
# o Dividir los datos en conjuntos de entrenamiento y prueba.
# o Entrenar un modelo de regresión logística y evaluar su precisión.

# %% [markdown]
# Prompt 4: crea un codigo python donde Entrenarás un árbol de decisión para clasificar si el valor del target es
# mayor que 140, y evaluarás su precisión sobre el conjunto de prueba.
# 2. Tareas:
# o Entrenar un modelo de árbol de decisión.
# o Realizar predicciones sobre el conjunto de prueba.
# o Evaluar el modelo utilizando la precisión.

# %% [markdown]
# Prompt 5: Crea un codigo python donde Implementarás un Random Forest con múltiples árboles de decisión para
# mejorar la robustez y precisión del modelo.
# 2. Tareas:
# o Entrenar un modelo de Random Forest con 100 árboles.
# o Realizar predicciones y evaluar la precisión del modelo.

# %% [markdown]
# Prompt 6: Crea un codigo python donde Evaluarás los modelos con métricas adicionales como la precisión, recall,
# F1-Score y el error cuadrático medio (MSE) para obtener una comprensión más
# profunda del rendimiento del modelo.
# 2. Tareas:
# o Calcular las métricas de evaluación: precisión, recall, F1-Score para el modelo
# de Random Forest.
# o Calcular el MSE en el modelo de regresión lineal.

# %% [markdown]
# *Prompt* 7:  Crea un codigo python donde aplicarás la técnica de validación cruzada para evaluar la
# consistencia del modelo de Random Forest utilizando 5 pliegues.
# 2. Tareas:
# o Aplicar la validación cruzada con 5 pliegues en el modelo de Random Forest.
# o Mostrar los resultados de cada pliegue y calcular el promedio de las
# puntuaciones.

# %% [markdown]
# Prompt 8:  Crea un codigo python donde Usarás el modelo ARIMA (AutoRegressive Integrated Moving Average)
# para analizar una serie temporal y realizar predicciones. ARIMA es comúnmente usado
# para modelar y predecir datos de series temporales.
# 2. Tareas:
# o Crear una serie temporal simulada.
# o Ajustar un modelo ARIMA y realizar predicciones de los valores futuros.

# %% [markdown]
# Prompt 9:  Crea un codigo python donde descompondrás una serie temporal en sus componentes
# principales: tendencia, estacionalidad y residuos.
# 2. Tareas:
# o Descomponer la serie temporal simulada utilizando la función
# seasonal_decompose.
# o Visualizar los componentes de la serie descompuesta.
